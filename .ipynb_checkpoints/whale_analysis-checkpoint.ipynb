# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns


# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
# 1. Read the Whale Portfolio daily returns from csv file
# 2. Identify and drop null values
# 3. Validate null values have been dropped

# %%
# Reading whale returns
whalepath = Path("./Resources/whale_returns.csv")
whalefile = pd.read_csv(whalepath, parse_dates=True, index_col = "Date", infer_datetime_format=True)
whaledf = pd.DataFrame(whalefile)
whaledf
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1060 rows x 4 columns]

# %%
# Count nulls
whaledf.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whaledf.dropna(inplace=True)
whaledf.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
# 1. Read the Algorithmic Daily returns from csv file
# 2. Identify and drop null values
# 3. Validate null values have been dropped

# %%
# Reading algorithmic returns
algopath = Path("./Resources/algo_returns.csv")
algofile = pd.read_csv(algopath, parse_dates=True, index_col = "Date", infer_datetime_format=True)
algodf = pd.DataFrame(algofile)

# %%
# Count nulls
algodf.isna().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algodf.dropna(inplace=True)
algodf.isna().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sppath = Path("./Resources/sp500_history.csv")
spfile = pd.read_csv(sppath, parse_dates=True, index_col = "Date", infer_datetime_format=True)
spdf = pd.DataFrame(spfile)

# %%
# Check Data Types
spdf.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
# Use Str Replace to clear non-numeric char's from "Close"
spdf["Close"] = spdf["Close"].str.replace("$","")
spdf["Close"] = spdf["Close"].str.replace(",","")

#Type_cast "Close" value as a float and confirm change
spdf["Close"] = spdf["Close"].astype("float")
sp_clean = spdf
sp_clean
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06
# ...             ...
# 2012-10-05  1460.93
# 2012-10-04  1461.40
# 2012-10-03  1450.99
# 2012-10-02  1445.75
# 2012-10-01  1444.49
#
# [1649 rows x 1 columns]

# %%
# Calculate Daily Returns
sp_clean = sp_clean.pct_change()

# %%
# Drop nulls
sp_clean = sp_clean.dropna()
sp_clean.isna().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
spfinal = sp_clean.rename(columns = {"Close":"S&P Returns"})
spfinal
# Out:
#             S&P Returns
# Date
# 2019-04-22    -0.008764
# 2019-04-18    -0.001011
# 2019-04-17    -0.001577
# 2019-04-16     0.002279
# 2019-04-15    -0.000509
# ...                 ...
# 2012-10-05     0.003469
# 2012-10-04     0.000322
# 2012-10-03    -0.007123
# 2012-10-02    -0.003611
# 2012-10-01    -0.000872
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
joined_df = pd.concat([whaledf, algodf, spfinal], axis="columns", join="inner")
joined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  S&P Returns
# Date
# 2015-03-03 -0.000949     0.004408
# 2015-03-04  0.002416    -0.001195
# 2015-03-05  0.004323     0.014378
# 2015-03-06 -0.011460    -0.003929
# 2015-03-09  0.001303     0.017254

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
joined_df.plot(figsize=(30,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + joined_df).cumprod() - 1

# Plot cumulative returns
cumulative_returns.plot(figsize=(30,20))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
joined_df.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
whale_std = whaledf.std()
algo_std = algodf.std()
print(f"The whale portfolio standard deviaions are:\n{whale_std}\nThe algorithm standard deviations are:\n{algo_std}")
# Out:
# The whale portfolio standard deviaions are:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64
# The algorithm standard deviations are:
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp_dev = spfinal.std()
print(f"The standard deviaion for the S&P 500 is:\n{sp_dev}\n")
# Determine which portfolios are riskier than the S&P 500
std_compare = cumulative_returns.std().sort_values(ascending = False)
print(f"Portfolios that have a greater standard deviation than the S&P are riskier than investing directly into the index funds, see chart:\n{std_compare}")
# Out:
# The standard deviaion for the S&P 500 is:
# S&P Returns    0.008135
# dtype: float64
#
# Portfolios that have a greater standard deviation than the S&P are riskier than investing directly into the index funds, see chart:
# BERKSHIRE HATHAWAY INC         0.241382
# Algo 1                         0.231772
# TIGER GLOBAL MANAGEMENT LLC    0.149652
# Algo 2                         0.131642
# S&P Returns                    0.114846
# PAULSON & CO.INC.              0.088447
# SOROS FUND MANAGEMENT LLC      0.073187
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = cumulative_returns.std() * np.sqrt(252)
annualized_std.sort_values(ascending=False)
# Out:
# BERKSHIRE HATHAWAY INC         3.831820
# Algo 1                         3.679263
# TIGER GLOBAL MANAGEMENT LLC    2.375658
# Algo 2                         2.089756
# S&P Returns                    1.823124
# PAULSON & CO.INC.              1.404053
# SOROS FUND MANAGEMENT LLC      1.161806
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
rolling_dev = cumulative_returns.rolling(window=21).std()
# Plot the rolling standard deviation
rolling_dev.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlate = cumulative_returns.corr()
# Display the correlation matrix
sns.heatmap(correlate, vmin=-1,vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
rolling_algo_covariance = cumulative_returns['Algo 1'].rolling(window=30).cov(cumulative_returns['S&P Returns'])

# Calculate variance of S&P 500
rolling_variance = cumulative_returns['S&P Returns'].rolling(window=30).var()

# Computing beta
rolling_algo_beta = rolling_algo_covariance / rolling_variance

# Plot beta trend
rolling_algo_beta.plot(figsize=(20,10), title="Rolling Beta of Algorithm Portfolio 1")
# Out:
# <AxesSubplot:title={'center':'Rolling Beta of Algorithm Portfolio 1'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
ewm = cumulative_returns["Algo 1"].ewm(span=21).mean()
ewm.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (
    cumulative_returns.mean() * 252 / (cumulative_returns.std() * np.sqrt(252))
)
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      10.784333
# PAULSON & CO.INC.             -22.231926
# TIGER GLOBAL MANAGEMENT LLC    15.724849
# BERKSHIRE HATHAWAY INC         10.472499
# Algo 1                         26.606482
# Algo 2                         10.463945
# S&P Returns                   -13.743079
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Based on analysis, Algorithm 1 has outperformed both the whales portfolios and the S&P 500, but Algorithm 2 did not.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
googpath = Path("./Resources/goog_historical.csv")
googfile = pd.read_csv(googpath, parse_dates=True, index_col = "Trade DATE", infer_datetime_format=True)
googdf = pd.DataFrame(googfile)
googdf
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40
# ...           ...      ...
# 2018-05-17   GOOG  1078.59
# 2018-05-16   GOOG  1081.77
# 2018-05-15   GOOG  1079.23
# 2018-05-14   GOOG  1100.20
# 2018-05-11   GOOG  1098.26
#
# [250 rows x 2 columns]

# %%
# Reading data from 2nd stock
aaplpath = Path("./Resources/aapl_historical.csv")
aaplfile = pd.read_csv(aaplpath, parse_dates=True, index_col = "Trade DATE", infer_datetime_format=True)
aapledf = pd.DataFrame(aaplfile)
aapledf.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
# Reading data from 3rd stock
costpath = Path("./Resources/cost_historical.csv")
costfile = pd.read_csv(costpath, parse_dates=True, index_col = "Trade DATE", infer_datetime_format=True)
costdf = pd.DataFrame(costfile)
costdf
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62
# ...           ...     ...
# 2018-05-17   COST  199.60
# 2018-05-16   COST  198.71
# 2018-05-15   COST  195.48
# 2018-05-14   COST  195.88
# 2018-05-11   COST  195.76
#
# [250 rows x 2 columns]

# %%
# Combine all stocks in a single DataFrame
combined = pd.concat([aapledf, costdf, googdf], axis="columns", join="inner")
combined
# Out:
#            Symbol    NOCP Symbol    NOCP Symbol     NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72   COST  243.47   GOOG  1162.38
# 2019-05-08   AAPL  202.90   COST  241.34   GOOG  1166.27
# 2019-05-07   AAPL  202.86   COST  240.18   GOOG  1174.10
# 2019-05-06   AAPL  208.48   COST  244.23   GOOG  1189.39
# 2019-05-03   AAPL  211.75   COST  244.62   GOOG  1185.40
# ...           ...     ...    ...     ...    ...      ...
# 2018-05-17   AAPL  186.99   COST  199.60   GOOG  1078.59
# 2018-05-16   AAPL  188.18   COST  198.71   GOOG  1081.77
# 2018-05-15   AAPL  186.44   COST  195.48   GOOG  1079.23
# 2018-05-14   AAPL  188.15   COST  195.88   GOOG  1100.20
# 2018-05-11   AAPL  188.59   COST  195.76   GOOG  1098.26
#
# [250 rows x 6 columns]

# %%
# Reset Date index
combined.sort_index(ascending=True, inplace=True)
combined
# Out:
#            Symbol    NOCP Symbol    NOCP Symbol     NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59   COST  195.76   GOOG  1098.26
# 2018-05-14   AAPL  188.15   COST  195.88   GOOG  1100.20
# 2018-05-15   AAPL  186.44   COST  195.48   GOOG  1079.23
# 2018-05-16   AAPL  188.18   COST  198.71   GOOG  1081.77
# 2018-05-17   AAPL  186.99   COST  199.60   GOOG  1078.59
# ...           ...     ...    ...     ...    ...      ...
# 2019-05-03   AAPL  211.75   COST  244.62   GOOG  1185.40
# 2019-05-06   AAPL  208.48   COST  244.23   GOOG  1189.39
# 2019-05-07   AAPL  202.86   COST  240.18   GOOG  1174.10
# 2019-05-08   AAPL  202.90   COST  241.34   GOOG  1166.27
# 2019-05-09   AAPL  200.72   COST  243.47   GOOG  1162.38
#
# [250 rows x 6 columns]

# %%
# Reorganize portfolio data by having a column per symbol
symbols = combined.drop(['Symbol'], axis=1)
symbols.columns = ['AAPL', 'COST', 'GOOG']
symbols.head()
# Out:
#               AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Calculate daily returns
daily_returns = symbols.pct_change()
daily_returns.head()
# Drop NAs
daily_returns.dropna(inplace=True)
# Display sample data
daily_returns.head()
# Out:
#                 AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
balanced = daily_returns.dot(weights)

# Display sample data
balanced.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
weight_add = pd.concat([daily_returns, balanced], axis ='columns', join='inner')
weight_add.rename(columns={0:'WEIGHTED'},inplace=True)
weight_add.head()
# Out:
#                 AAPL      COST      GOOG  WEIGHTED
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766  0.000015
# 2018-05-15 -0.009088 -0.002042 -0.019060 -0.010064
# 2018-05-16  0.009333  0.016523  0.002354  0.009403
# 2018-05-17 -0.006324  0.004479 -0.002940 -0.001595
# 2018-05-18 -0.003637 -0.003206 -0.011339 -0.006061

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
weighted = weight_add.dropna()
weighted.head()
# Out:
#                 AAPL      COST      GOOG  WEIGHTED
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766  0.000015
# 2018-05-15 -0.009088 -0.002042 -0.019060 -0.010064
# 2018-05-16  0.009333  0.016523  0.002354  0.009403
# 2018-05-17 -0.006324  0.004479 -0.002940 -0.001595
# 2018-05-18 -0.003637 -0.003206 -0.011339 -0.006061

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
volatility = weighted.std() * np.sqrt(252)
volatility.sort_values(inplace=True)
volatility
# Out:
# COST        0.209320
# WEIGHTED    0.210262
# GOOG        0.263554
# AAPL        0.296955
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_port_dev = weighted.rolling(window=21).std()
# Plot rolling standard deviation
rolling_port_dev.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Trade DATE'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation = weighted.corr()
sns.heatmap(correlation, vmin=-1,vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# Covariance for each stock as well as the 33% weighted portfolio
rolling_aapl_covariance = weighted['AAPL'].rolling(window=60).cov(cumulative_returns['S&P Returns'])
rolling_cost_covariance = weighted['COST'].rolling(window=60).cov(cumulative_returns['S&P Returns'])
rolling_goog_covariance = weighted['GOOG'].rolling(window=60).cov(cumulative_returns['S&P Returns'])
rolling_weight_covariance = weighted['WEIGHTED'].rolling(window=60).cov(cumulative_returns['S&P Returns'])

# Calculate variance of S&P 500
sixty_day_variance = cumulative_returns['S&P Returns'].rolling(window=60).var()

# Computing beta
rolling_aapl_beta = rolling_aapl_covariance / sixty_day_variance
rolling_cost_beta = rolling_cost_covariance / sixty_day_variance
rolling_goog_beta = rolling_goog_covariance / sixty_day_variance
rolling_weight_beta = rolling_weight_covariance / sixty_day_variance

# Plot beta trend
ax = rolling_aapl_beta.plot(figsize=(20,10), title="Rolling Beta of Investment Portfolio")
rolling_cost_beta.plot(ax=ax)
rolling_goog_beta.plot(ax=ax)
rolling_weight_beta.plot(ax=ax)

ax.legend(['AAPL', 'COST', 'GOOG', 'WEIGHTED'])

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
sharpe_ratios = (weighted.mean() * 252) / (weighted.std() * np.sqrt(252))
sharpe_ratios
# Out:
# AAPL        0.361306
# COST        1.160482
# GOOG        0.349657
# WEIGHTED    0.701280
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
#
# Costco alone outperforms the other stocks in the portfolio, including the weighted option, see cumulative profits comparison graph below.

# %%
initial_investment = 10000
cumulative_returns = (1 + weighted).cumprod()
cumulative_profits = (initial_investment * cumulative_returns)

# Plot cumulative returns
cumulative_profits.plot(figsize=(30,20))
# Out:
# <AxesSubplot:xlabel='Trade DATE'>
